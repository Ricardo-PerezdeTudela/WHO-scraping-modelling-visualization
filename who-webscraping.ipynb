# %%
import os
import re
import numpy as np
import pandas as pd
from urllib.request import urlopen
import wget
from bs4 import BeautifulSoup
import PyPDF2
import camelot
import tabula
import datetime
import matplotlib.pyplot as plt

# %%
def extract_df_from_pdf(filename):
    
    reader = PyPDF2.PdfFileReader(open(filename, "rb"))
    
    # Extract the date from the 1st page and store it:
    page = reader.getPage(0)
    text = page.extractText()
    text_tolist = text.split()
    months = ["January", "February", "March", "April", "May", "June", "July"]
    for month in months:
        if month in text_tolist:
            idx = text_tolist.index(month)
    d = text_tolist[idx-1]
    m = text_tolist[idx].replace("January","01").replace("February","02").replace("March","03").replace("April","04").replace("May","05").replace("June","06")
    y = text_tolist[idx+1].replace("*","")
    date = datetime.date(int(y), int(m), int(d))
    
    # As pdf scraping is tricky, the packages tabula and camelot are tried. 
    # If tabula fails, it tries camelot. 
    # If both fail, the function will return no dataframe at all.
    try:
        tables = tabula.read_pdf(filename, pages = "all", multiple_tables = True)
        print(date,"tabula")
    except:
        try:
            tables_camelot = camelot.read_pdf(filename, 
                              pages='all', 
                              flavour = 'stream',
                              line_scale=60, shift_text=[''], 
                              flag_size=True)#,
                              #split_text=True)#, 
                              #strip_text='.\n')
            # camelot returns a list of objects that have the property df, 
            # therefore tables[0].df is the first dataframe.
            # We'll create a list of dataframes, which is simpler and 
            # it matches with what tabula does:
            tables = []
            for table in tables_camelot:
                tables.append(table.df)
            print(date,"camelot")
        except:
            return

    # Identify the LAST table that contains the appropriate headers. 
    # I'll look for the words 'country', 'case' AND 'death'.
    for it, table in enumerate(tables):
        text = table.to_string().casefold()
        list_words = ["country", "case", "death", "new"]
        res = [word for word in list_words if word in text]
        if len(res) == len(list_words):
            itable = it
    columns = tables[itable].columns
        
    # The names of the columns change from one pdf to other
    # Here we identify the columns corresponding to the 
    # text strings in the array list_str.
    # Then, change their original name to what is in the array.
    # This way, all the tables will have the same name for the columns. 
    # It is important that 'new confirmed' comes before 'confirmed'!
    columns_clean = ["Country", "New conf", "Conf", "New deaths", "Deaths"]
    list_idx = []
    list_idx_clean = []
    for idx, col in enumerate(columns):
        for idx_clean, str_clean in enumerate(columns_clean):
            if idx_clean not in list_idx_clean:
                match = []
                for word in str_clean.split():
                    text_column = tables[itable].iloc[:,idx].to_string().casefold()
                    if word == "Country":
                        match.append(word.casefold() in text_column)
                    else:
                        match.append(word.casefold() in text_column and "china" not in text_column)
                if match != [] and all(match) and idx not in list_idx:
                    list_idx.append(idx)
                    list_idx_clean.append(idx_clean)

    idx_country = list_idx[0]
    
    # Append data to list "tot":
    countries = ["China", "Spain", "Korea", "Italy", "Germany", "United States of America"]
    tot = []
    for idx_table, table in enumerate(tables):
        dd = table
        if len(dd.columns) > idx_country:# and idx_table >= itable:
            for country in countries:
                # Look for the name of the country in the corresponding column:
                try:
                    #x = dd.iloc[:,idx_country].str.contains(country)==True
                    x = dd.iloc[:,idx_country].str.casefold() == country.casefold()
                    if x.any():
                        tot.append(dd[x].to_numpy().ravel())
                except:
                    x = []

    # Assign columns:
    dft = pd.DataFrame(data=tot).iloc[:,list_idx]
    dft.columns = [columns_clean[i] for i in list_idx_clean]
    dft["Date"] = date
    
    # Fill any empty gap with NaN:
    dft = dft.replace(r'^\s*$', np.nan, regex=True)
    #dft2 = dft2.replace(r'^ *$', "_", regex=True)

    # Split columns if necessary:
    str = "New conf"
    x = dft[str].str.contains("\(")
    if x.any():
        dft[["Conf", str]] = dft[str].str.split(pat="\(", expand=True).fillna(value=0)
        dft[["Deaths", "New deaths"]] = dft["New deaths"].str.split(pat="\(", expand=True).fillna(value=0)
    
    # Clean data
    # Remove parenthesis, HTML tags and non-alphabet chars:
    dft = dft.replace("\(","",regex=True).replace("\)","",regex=True)
    dft = dft.replace("<.*?>","",regex=True).replace("([^\s\w]|_)+","",regex=True)
    
    # Remove white spaces in numeric columns:
    #dft2.select_dtypes(include=['int']) =  dft2.select_dtypes(include=['int']).replace(" ","")
    dft[["Conf", "New conf", "Deaths", "New deaths"]] = dft[["Conf", "New conf", "Deaths", "New deaths"]].replace("\s+","",regex=True)
    # Remove rows containing the word "development":
    for intruder in ["development", "spread"]:
        dft = dft[~dft.Country.str.contains(intruder)]

    return dft

# %%
url0 = "https://www.who.int"
url = url0 + "/emergencies/diseases/novel-coronavirus-2019/situation-reports/"
html = urlopen(url)
soup = BeautifulSoup(html, features="html.parser")

# %%
# From all the href links, select those which contain the word "Situation":
links = [a for a in soup.findAll('a', href=True) if "Situation" in a.text]

# %%
print(len(links))
# Out:
# 141

# %%
list_df = []
for link in links:
    wfile = url0 + link["href"]
    ff = wfile.rsplit('/', 1)[-1].split('?',1)[0]
    print(ff)
    if not os.path.isfile(ff):
        filename = wget.download(wfile)
    try:
        df = extract_df_from_pdf(ff)
    except:
        print("Error!")
    #except ValueError:
    #    print("could not be read properly")
    #except IndexError:
    #    print("IndexError!")
    list_df.append(df)
# Out:
# 20200610-covid-19-sitrep-142.pdf
# 2020-06-10 tabula
# 20200609-covid-19-sitrep-141.pdf
# 2020-06-09 tabula
# 20200608-covid-19-sitrep-140.pdf
# 2020-06-08 tabula
# 20200607-covid-19-sitrep-139.pdf
# 2020-06-07 tabula
# 20200606-covid-19-sitrep-138.pdf
# 2020-06-06 tabula
# 20200605-covid-19-sitrep-137.pdf
# 2020-06-05 tabula
# 20200604-covid-19-sitrep-136.pdf
# 2020-06-04 tabula
# 20200603-covid-19-sitrep-135.pdf
# 2020-06-03 tabula
# 20200602-covid-19-sitrep-134.pdf
# 2020-06-02 tabula
# 20200601-covid-19-sitrep-133.pdf
# 2020-06-01 tabula
# 20200531-covid-19-sitrep-132.pdf
# 2020-05-31 tabula
# 20200530-covid-19-sitrep-131.pdf
# 2020-05-30 tabula
# 20200529-covid-19-sitrep-130.pdf
# 2020-05-09 tabula
# 20200528-covid-19-sitrep-129.pdf
# 2020-05-08 tabula
# 20200527-covid-19-sitrep-128.pdf
# 2020-05-07 tabula
# 20200526-covid-19-sitrep-127.pdf
# 2020-05-06 tabula
# 20200525-covid-19-sitrep-126.pdf
# 2020-05-05 tabula
# 20200524-covid-19-sitrep-125.pdf
# 2020-05-04 tabula
# 20200523-covid-19-sitrep-124.pdf
# 2020-05-03 tabula
# 20200522-covid-19-sitrep-123.pdf
# 2020-05-02 tabula
# 20200521-covid-19-sitrep-122.pdf
# 2020-05-21 tabula
# 20200520-covid-19-sitrep-121.pdf
# 2020-05-20 tabula
# 20200519-covid-19-sitrep-120.pdf
# 2020-05-09 tabula
# 20200518-covid-19-sitrep-119.pdf
# 2020-05-08 tabula
# 20200517-covid-19-sitrep-118.pdf
# 2020-05-07 tabula
# 20200516-covid-19-sitrep-117.pdf
# 2020-05-06 tabula
# 20200515-covid-19-sitrep-116.pdf
# 2020-05-05 tabula
# 20200514-covid-19-sitrep-115.pdf
# 2020-05-04 tabula
# 20200513-covid-19-sitrep-114.pdf
# 2020-05-03 tabula
# 20200512-covid-19-sitrep-113.pdf
# 2020-05-12 tabula
# 20200511-covid-19-sitrep-112.pdf
# 2020-05-11 tabula
# 20200510covid-19-sitrep-111.pdf
# 2020-05-10 tabula
# 20200509covid-19-sitrep-110.pdf
# 2020-05-09 tabula
# 20200508covid-19-sitrep-109.pdf
# 2020-05-08 tabula
# 20200507covid-19-sitrep-108.pdf
# 2020-05-07 tabula
# 20200506covid-19-sitrep-107.pdf
# 2020-05-06 tabula
# 20200505covid-19-sitrep-106.pdf
# 2020-05-05 tabula
# 20200504-covid-19-sitrep-105.pdf
# 2020-05-04 tabula
# 20200503-covid-19-sitrep-104.pdf
# 2020-05-03 tabula
# 20200502-covid-19-sitrep-103.pdf
# 2020-05-02 tabula
# 20200501-covid-19-sitrep.pdf
# 2020-05-01 tabula
# 20200430-sitrep-101-covid-19.pdf
# 2020-04-30 tabula
# 20200429-sitrep-100-covid-19.pdf
# 2020-04-29 tabula
# 20200428-sitrep-99-covid-19.pdf
# 2020-04-28 tabula
# Error!
# 20200427-sitrep-98-covid-19.pdf
# 2020-04-27 tabula
# 20200426-sitrep-97-covid-19.pdf
# 2020-04-26 tabula
# 20200425-sitrep-96-covid-19.pdf
# 2020-04-25 tabula
# 20200424-sitrep-95-covid-19.pdf
# 2020-04-24 tabula
# 20200423-sitrep-94-covid-19.pdf
# 2020-04-23 tabula
# 20200422-sitrep-93-covid-19.pdf
# 2020-04-22 tabula
# 20200421-sitrep-92-covid-19.pdf
# 2020-04-21 tabula
# 20200420-sitrep-91-covid-19.pdf
# 2020-04-20 tabula
# 20200419-sitrep-90-covid-19.pdf
# 2020-04-19 tabula
# 20200418-sitrep-89-covid-19.pdf
# 2020-04-18 tabula
# 20200417-sitrep-88-covid-191b6cccd94f8b4f219377bff55719a6ed.pdf
# 2020-04-17 tabula
# 20200416-sitrep-87-covid-19.pdf
# 2020-04-16 tabula
# 20200415-sitrep-86-covid-19.pdf
# 2020-04-15 tabula
# 20200414-sitrep-85-covid-19.pdf
# 2020-04-14 tabula
# 20200413-sitrep-84-covid-19.pdf
# 2020-04-13 tabula
# 20200412-sitrep-83-covid-19.pdf
# 2020-04-12 tabula
# 20200411-sitrep-82-covid-19.pdf
# 2020-04-11 tabula
# 20200410-sitrep-81-covid-19.pdf
# 2020-04-10 tabula
# 20200409-sitrep-80-covid-19.pdf
# 2020-04-09 tabula
# 20200408-sitrep-79-covid-19.pdf
# 2020-04-08 tabula
# 20200407-sitrep-78-covid-19.pdf
# 2020-04-07 tabula
# 20200406-sitrep-77-covid-19.pdf
# 2020-04-06 tabula
# 20200405-sitrep-76-covid-19.pdf
# 2020-04-05 tabula
# 20200404-sitrep-75-covid-19.pdf
# 2020-04-04 tabula
# 20200403-sitrep-74-covid-19-mp.pdf
# 2020-04-03 tabula
# 20200402-sitrep-73-covid-19.pdf
# 2020-04-02 tabula
# 20200401-sitrep-72-covid-19.pdf
# 2020-04-01 tabula
# 20200330-sitrep-70-covid-19.pdf
# 2020-03-30 tabula
# 20200329-sitrep-69-covid-19.pdf
# 2020-03-29 tabula
# 20200328-sitrep-68-covid-19.pdf
# 2020-03-28 tabula
# 20200327-sitrep-67-covid-19.pdf
# 2020-03-27 tabula
# 20200326-sitrep-66-covid-19.pdf
# 2020-03-26 tabula
# 20200325-sitrep-65-covid-19.pdf
# 2020-03-25 tabula
# 20200324-sitrep-64-covid-19.pdf
# 2020-03-24 tabula
# 20200323-sitrep-63-covid-19.pdf
# 2020-03-23 tabula
# 20200322-sitrep-62-covid-19.pdf
# 2020-03-21 tabula
# 20200321-sitrep-61-covid-19.pdf
# 2020-03-20 tabula
# 20200320-sitrep-60-covid-19.pdf
# 2020-03-19 tabula
# 20200319-sitrep-59-covid-19.pdf
# 2020-03-19 tabula
# 20200318-sitrep-58-covid-19.pdf
# 2020-03-18 tabula
# 20200317-sitrep-57-covid-19.pdf
# 2020-03-17 tabula
# 20200316-sitrep-56-covid-19.pdf
# 2020-03-16 tabula
# 20200315-sitrep-55-covid-19.pdf
# 2020-03-15 tabula
# 20200314-sitrep-54-covid-19.pdf
# 2020-03-14 tabula
# 20200313-sitrep-53-covid-19.pdf
# 2020-03-13 tabula
# 20200312-sitrep-52-covid-19.pdf
# 2020-03-12 tabula
# 20200311-sitrep-51-covid-19.pdf
# 2020-03-11 tabula
# 20200310-sitrep-50-covid-19.pdf
# 2020-03-10 tabula
# 20200309-sitrep-49-covid-19.pdf
# 2020-03-09 tabula
# 20200308-sitrep-48-covid-19.pdf
# 2020-03-08 tabula
# 20200307-sitrep-47-covid-19.pdf
# 2020-03-07 tabula
# 20200306-sitrep-46-covid-19.pdf
# 2020-03-06 tabula
# 20200305-sitrep-45-covid-19.pdf
# 2020-03-05 tabula
# 20200304-sitrep-44-covid-19.pdf
# 2020-03-04 tabula
# 20200303-sitrep-43-covid-19.pdf
# 2020-03-03 tabula
# 20200302-sitrep-42-covid-19.pdf
# 2020-03-02 tabula
# 20200301-sitrep-41-covid-19.pdf
# 2020-03-01 tabula
# 20200229-sitrep-40-covid-19.pdf
# 2020-02-29 tabula
# 20200228-sitrep-39-covid-19.pdf
# 2020-02-28 tabula
# 20200227-sitrep-38-covid-19.pdf
# 2020-02-27 tabula
# 20200226-sitrep-37-covid-19.pdf
# 2020-02-06 tabula
# 20200225-sitrep-36-covid-19.pdf
# 2020-02-25 tabula
# 20200224-sitrep-35-covid-19.pdf
# 2020-02-24 tabula
# 20200223-sitrep-34-covid-19.pdf
# 2020-02-23 tabula
# 20200222-sitrep-33-covid-19.pdf
# 2020-02-22 tabula
# 20200221-sitrep-32-covid-19.pdf
# 2020-02-21 tabula
# 20200220-sitrep-31-covid-19.pdf
# 2020-02-20 tabula
# Error!
# 20200219-sitrep-30-covid-19.pdf
# 2020-02-19 tabula
# Error!
# 20200218-sitrep-29-covid-19.pdf
# 2020-02-18 tabula
# 20200217-sitrep-28-covid-19.pdf
# 2020-02-17 tabula
# 20200216-sitrep-27-covid-19.pdf
# 2020-02-16 tabula
# 20200215-sitrep-26-covid-19.pdf
# 2020-02-15 tabula
# 20200214-sitrep-25-covid-19.pdf
# 2020-02-14 tabula
# 20200213-sitrep-24-covid-19.pdf
# 2020-02-13 tabula
# 20200212-sitrep-23-ncov.pdf
# 2020-02-12 tabula
# 20200211-sitrep-22-ncov.pdf
# 2020-02-11 tabula
# 20200210-sitrep-21-ncov.pdf
# 2020-02-10 tabula
# 20200209-sitrep-20-ncov.pdf
# 2020-02-09 tabula
# 20200208-sitrep-19-ncov.pdf
# 2020-02-08 tabula
# 20200207-sitrep-18-ncov.pdf
# 2020-02-07 tabula
# 20200206-sitrep-17-ncov.pdf
# 2020-02-06 tabula
# Error!
# 20200205-sitrep-16-ncov.pdf
# 2020-02-05 tabula
# Error!
# 20200204-sitrep-15-ncov.pdf
# 2020-02-04 tabula
# Error!
# 20200203-sitrep-14-ncov.pdf
# 2020-02-03 tabula
# Error!
# 20200202-sitrep-13-ncov-v3.pdf
# 2020-02-02 tabula
# Error!
# 20200201-sitrep-12-ncov.pdf
# 2020-02-01 tabula
# Error!
# 20200131-sitrep-11-ncov.pdf
# 2020-01-01 tabula
# Error!
# 20200130-sitrep-10-ncov.pdf
# 2020-01-30 tabula
# Error!
# 20200129-sitrep-9-ncov-v2.pdf
# Error!
# 20200128-sitrep-8-ncov-cleared.pdf
# Error!
# 20200127-sitrep-7-2019--ncov.pdf
# 2020-01-27 tabula
# Error!
# 20200126-sitrep-6-2019--ncov.pdf
# 2020-01-06 tabula
# Error!
# 20200125-sitrep-5-2019-ncov.pdf
# 2020-01-05 tabula
# Error!
# 20200124-sitrep-4-2019-ncov.pdf
# 2020-01-04 tabula
# Error!
# 20200123-sitrep-3-2019-ncov.pdf
# 2020-01-23 tabula
# Error!
# 20200122-sitrep-2-2019-ncov.pdf
# 2020-01-21 tabula
# Error!
# 20200121-sitrep-1-2019-ncov.pdf
# 2020-01-20 tabula
# Error!

# %%
print(len(list_df))
# Out:
# 141

# %%
final = pd.concat(list_df, ignore_index=True)

# %%
pd.unique(final["Date"])
# Out:
# array([datetime.date(2020, 6, 10), datetime.date(2020, 6, 9),
#        datetime.date(2020, 6, 8), datetime.date(2020, 6, 7),
#        datetime.date(2020, 6, 6), datetime.date(2020, 6, 5),
#        datetime.date(2020, 6, 4), datetime.date(2020, 6, 3),
#        datetime.date(2020, 6, 2), datetime.date(2020, 6, 1),
#        datetime.date(2020, 5, 31), datetime.date(2020, 5, 30),
#        datetime.date(2020, 5, 9), datetime.date(2020, 5, 8),
#        datetime.date(2020, 5, 7), datetime.date(2020, 5, 6),
#        datetime.date(2020, 5, 5), datetime.date(2020, 5, 4),
#        datetime.date(2020, 5, 3), datetime.date(2020, 5, 2),
#        datetime.date(2020, 5, 21), datetime.date(2020, 5, 20),
#        datetime.date(2020, 5, 12), datetime.date(2020, 5, 11),
#        datetime.date(2020, 5, 10), datetime.date(2020, 5, 1),
#        datetime.date(2020, 4, 30), datetime.date(2020, 4, 29),
#        datetime.date(2020, 4, 27), datetime.date(2020, 4, 26),
#        datetime.date(2020, 4, 25), datetime.date(2020, 4, 24),
#        datetime.date(2020, 4, 23), datetime.date(2020, 4, 22),
#        datetime.date(2020, 4, 21), datetime.date(2020, 4, 20),
#        datetime.date(2020, 4, 19), datetime.date(2020, 4, 18),
#        datetime.date(2020, 4, 17), datetime.date(2020, 4, 16),
#        datetime.date(2020, 4, 15), datetime.date(2020, 4, 14),
#        datetime.date(2020, 4, 13), datetime.date(2020, 4, 12),
#        datetime.date(2020, 4, 11), datetime.date(2020, 4, 10),
#        datetime.date(2020, 4, 9), datetime.date(2020, 4, 8),
#        datetime.date(2020, 4, 7), datetime.date(2020, 4, 6),
#        datetime.date(2020, 4, 5), datetime.date(2020, 4, 4),
#        datetime.date(2020, 4, 3), datetime.date(2020, 4, 2),
#        datetime.date(2020, 4, 1), datetime.date(2020, 3, 30),
#        datetime.date(2020, 3, 29), datetime.date(2020, 3, 28),
#        datetime.date(2020, 3, 27), datetime.date(2020, 3, 26),
#        datetime.date(2020, 3, 25), datetime.date(2020, 3, 24),
#        datetime.date(2020, 3, 23), datetime.date(2020, 3, 21),
#        datetime.date(2020, 3, 20), datetime.date(2020, 3, 19),
#        datetime.date(2020, 3, 18), datetime.date(2020, 3, 17),
#        datetime.date(2020, 3, 16), datetime.date(2020, 3, 15),
#        datetime.date(2020, 3, 14), datetime.date(2020, 3, 13),
#        datetime.date(2020, 3, 12), datetime.date(2020, 3, 11),
#        datetime.date(2020, 3, 10), datetime.date(2020, 3, 9),
#        datetime.date(2020, 3, 8), datetime.date(2020, 3, 7),
#        datetime.date(2020, 3, 6), datetime.date(2020, 3, 5),
#        datetime.date(2020, 3, 4), datetime.date(2020, 3, 3),
#        datetime.date(2020, 3, 2), datetime.date(2020, 3, 1),
#        datetime.date(2020, 2, 29), datetime.date(2020, 2, 28),
#        datetime.date(2020, 2, 27), datetime.date(2020, 2, 6),
#        datetime.date(2020, 2, 25), datetime.date(2020, 2, 24),
#        datetime.date(2020, 2, 23), datetime.date(2020, 2, 22),
#        datetime.date(2020, 2, 21), datetime.date(2020, 2, 18),
#        datetime.date(2020, 2, 17), datetime.date(2020, 2, 16),
#        datetime.date(2020, 2, 15), datetime.date(2020, 2, 14),
#        datetime.date(2020, 2, 13), datetime.date(2020, 2, 12),
#        datetime.date(2020, 2, 11), datetime.date(2020, 2, 10),
#        datetime.date(2020, 2, 9), datetime.date(2020, 2, 8),
#        datetime.date(2020, 2, 7)], dtype=object)

# %%
final.to_csv("corona-who-14.csv", sep=",")
